# %%
import numpy as np
import pandas as pd

dF = pd.read_csv('titanic.csv', index_col='PassengerId')
dF.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# Какое количество мужчин и женщин ехало на корабле? В качестве ответа приведите два числа через пробел.
#
# Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.
#
# Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.
#
# Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.
#
# Коррелируют ли число братьев/сестер/супругов с числом родителей/детей? Посчитайте корреляцию Пирсона между признаками SibSp и Parch.
#
# Какое самое популярное женское имя на корабле? Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию. Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения их на женские и мужские.

# %%
dF.dtypes

# %% [markdown]
# 1.
# Какое количество мужчин и женщин ехало на корабле? В качестве ответа приведите два числа через пробел.

# %%
dF.groupby(['Sex']).count()

# %% [markdown]
# 2. Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
dF.groupby(['Survived']).count()

# %%
dF.mean()

# %% [markdown]
# 3. Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.

# %%
data = dF.groupby(['Pclass']).count()
print(data)

# %%
round(((data.iloc[0][1])/len(dF)*100),2)

# %% [markdown]
# 4. Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.

# %%
print(dF['Age'].mean())
print(dF['Age'].median())

# %% [markdown]
# 5. Коррелируют ли число братьев/сестер/супругов с числом родителей/детей? Посчитайте корреляцию Пирсона между признаками SibSp и Parch.

# %%
dF.corr(method='pearson')

# %%
res5 = dF.corr(method='pearson').iloc[4][3]
print(round(res5,2))

# %% [markdown]
# ### 6. Какое самое популярное женское имя на корабле? Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию. Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения их на женские и мужские.

# %%
dF[['Name', 'Sex']].head()
dF.info()

# %%
dF['Sex'][dF['Sex'] == 'male'] = 1
dF['Sex'][dF['Sex'] == 'female'] = 0
dF.head(5)
# Out:
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0
# 3                                       Heikkinen, Miss. Laina   0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0
# 5                                     Allen, Mr. William Henry   1  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
dF1 = dF[dF['Sex'] == 0]
dF1
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 15                  0       3
# 16                  1       2
# 19                  0       3
# 20                  1       3
# 23                  1       3
# 25                  0       3
# 26                  1       3
# 29                  1       3
# 32                  1       1
# 33                  1       3
# 39                  0       3
# 40                  1       3
# 41                  0       3
# 42                  0       2
# 44                  1       2
# 45                  1       3
# 48                  1       3
# 50                  0       3
# 53                  1       1
# 54                  1       2
# 57                  1       2
# 59                  1       2
# 62                  1       1
# ...               ...     ...
# 808                 0       3
# 810                 1       1
# 814                 0       3
# 817                 0       3
# 821                 1       1
# 824                 1       3
# 830                 1       1
# 831                 1       3
# 836                 1       1
# 843                 1       1
# 850                 1       1
# 853                 0       3
# 854                 1       1
# 855                 0       2
# 856                 1       3
# 857                 1       1
# 859                 1       3
# 863                 1       1
# 864                 0       3
# 866                 1       2
# 867                 1       2
# 872                 1       1
# 875                 1       2
# 876                 1       3
# 880                 1       1
# 881                 1       2
# 883                 0       3
# 886                 0       3
# 888                 1       1
# 889                 0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0
# 3                                       Heikkinen, Miss. Laina   0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)   0  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)   0  14.0
# 11                             Sandstrom, Miss. Marguerite Rut   0   4.0
# 12                                    Bonnell, Miss. Elizabeth   0  58.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina   0  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)    0  55.0
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...   0  31.0
# 20                                     Masselmani, Mrs. Fatima   0   NaN
# 23                                 McGowan, Miss. Anna "Annie"   0  15.0
# 25                               Palsson, Miss. Torborg Danira   0   8.0
# 26           Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...   0  38.0
# 29                               O'Dwyer, Miss. Ellen "Nellie"   0   NaN
# 32              Spencer, Mrs. William Augustus (Marie Eugenie)   0   NaN
# 33                                    Glynn, Miss. Mary Agatha   0   NaN
# 39                          Vander Planke, Miss. Augusta Maria   0  18.0
# 40                                 Nicola-Yarred, Miss. Jamila   0  14.0
# 41              Ahlin, Mrs. Johan (Johanna Persdotter Larsson)   0  40.0
# 42           Turpin, Mrs. William John Robert (Dorothy Ann ...   0  27.0
# 44                    Laroche, Miss. Simonne Marie Anne Andree   0   3.0
# 45                               Devaney, Miss. Margaret Delia   0  19.0
# 48                                   O'Driscoll, Miss. Bridget   0   NaN
# 50               Arnold-Franchi, Mrs. Josef (Josefine Franchi)   0  18.0
# 53                    Harper, Mrs. Henry Sleeper (Myna Haxtun)   0  49.0
# 54           Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...   0  29.0
# 57                                           Rugg, Miss. Emily   0  21.0
# 59                                West, Miss. Constance Mirium   0   5.0
# 62                                         Icard, Miss. Amelie   0  38.0
# ...                                                        ...  ..   ...
# 808                            Pettersson, Miss. Ellen Natalia   0  18.0
# 810             Chambers, Mrs. Norman Campbell (Bertha Griggs)   0  33.0
# 814                         Andersson, Miss. Ebba Iris Alfrida   0   6.0
# 817                               Heininen, Miss. Wendla Maria   0  23.0
# 821          Hays, Mrs. Charles Melville (Clara Jennings Gr...   0  52.0
# 824                                         Moor, Mrs. (Beila)   0  27.0
# 830                  Stone, Mrs. George Nelson (Martha Evelyn)   0  62.0
# 831                    Yasbeck, Mrs. Antoni (Selini Alexander)   0  15.0
# 836                                Compton, Miss. Sara Rebecca   0  39.0
# 843                                    Serepeca, Miss. Augusta   0  30.0
# 850               Goldenberg, Mrs. Samuel L (Edwiga Grabowska)   0   NaN
# 853                                    Boulos, Miss. Nourelain   0   9.0
# 854                                  Lines, Miss. Mary Conover   0  16.0
# 855              Carter, Mrs. Ernest Courtenay (Lilian Hughes)   0  44.0
# 856                                 Aks, Mrs. Sam (Leah Rosen)   0  18.0
# 857                 Wick, Mrs. George Dennick (Mary Hitchcock)   0  45.0
# 859                      Baclini, Mrs. Solomon (Latifa Qurban)   0  24.0
# 863          Swift, Mrs. Frederick Joel (Margaret Welles Ba...   0  48.0
# 864                          Sage, Miss. Dorothy Edith "Dolly"   0   NaN
# 866                                   Bystrom, Mrs. (Karolina)   0  42.0
# 867                               Duran y More, Miss. Asuncion   0  27.0
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   0  47.0
# 875                      Abelson, Mrs. Samuel (Hannah Wizosky)   0  28.0
# 876                           Najib, Miss. Adele Kiamie "Jane"   0  15.0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   0  56.0
# 881               Shelley, Mrs. William (Imanita Parrish Hall)   0  25.0
# 883                               Dahlberg, Miss. Gerda Ulrika   0  22.0
# 886                       Rice, Mrs. William (Margaret Norton)   0  39.0
# 888                               Graham, Miss. Margaret Edith   0  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"   0   NaN
#
#              SibSp  Parch            Ticket      Fare Cabin Embarked
# PassengerId
# 2                1      0          PC 17599   71.2833   C85        C
# 3                0      0  STON/O2. 3101282    7.9250   NaN        S
# 4                1      0            113803   53.1000  C123        S
# 9                0      2            347742   11.1333   NaN        S
# 10               1      0            237736   30.0708   NaN        C
# 11               1      1           PP 9549   16.7000    G6        S
# 12               0      0            113783   26.5500  C103        S
# 15               0      0            350406    7.8542   NaN        S
# 16               0      0            248706   16.0000   NaN        S
# 19               1      0            345763   18.0000   NaN        S
# 20               0      0              2649    7.2250   NaN        C
# 23               0      0            330923    8.0292   NaN        Q
# 25               3      1            349909   21.0750   NaN        S
# 26               1      5            347077   31.3875   NaN        S
# 29               0      0            330959    7.8792   NaN        Q
# 32               1      0          PC 17569  146.5208   B78        C
# 33               0      0            335677    7.7500   NaN        Q
# 39               2      0            345764   18.0000   NaN        S
# 40               1      0              2651   11.2417   NaN        C
# 41               1      0              7546    9.4750   NaN        S
# 42               1      0             11668   21.0000   NaN        S
# 44               1      2     SC/Paris 2123   41.5792   NaN        C
# 45               0      0            330958    7.8792   NaN        Q
# 48               0      0             14311    7.7500   NaN        Q
# 50               1      0            349237   17.8000   NaN        S
# 53               1      0          PC 17572   76.7292   D33        C
# 54               1      0              2926   26.0000   NaN        S
# 57               0      0        C.A. 31026   10.5000   NaN        S
# 59               1      2        C.A. 34651   27.7500   NaN        S
# 62               0      0            113572   80.0000   B28      NaN
# ...            ...    ...               ...       ...   ...      ...
# 808              0      0            347087    7.7750   NaN        S
# 810              1      0            113806   53.1000    E8        S
# 814              4      2            347082   31.2750   NaN        S
# 817              0      0  STON/O2. 3101290    7.9250   NaN        S
# 821              1      1             12749   93.5000   B69        S
# 824              0      1            392096   12.4750  E121        S
# 830              0      0            113572   80.0000   B28      NaN
# 831              1      0              2659   14.4542   NaN        C
# 836              1      1          PC 17756   83.1583   E49        C
# 843              0      0            113798   31.0000   NaN        C
# 850              1      0             17453   89.1042   C92        C
# 853              1      1              2678   15.2458   NaN        C
# 854              0      1          PC 17592   39.4000   D28        S
# 855              1      0            244252   26.0000   NaN        S
# 856              0      1            392091    9.3500   NaN        S
# 857              1      1             36928  164.8667   NaN        S
# 859              0      3              2666   19.2583   NaN        C
# 863              0      0             17466   25.9292   D17        S
# 864              8      2          CA. 2343   69.5500   NaN        S
# 866              0      0            236852   13.0000   NaN        S
# 867              1      0     SC/PARIS 2149   13.8583   NaN        C
# 872              1      1             11751   52.5542   D35        S
# 875              1      0         P/PP 3381   24.0000   NaN        C
# 876              0      0              2667    7.2250   NaN        C
# 880              0      1             11767   83.1583   C50        C
# 881              0      1            230433   26.0000   NaN        S
# 883              0      0              7552   10.5167   NaN        S
# 886              0      5            382652   29.1250   NaN        Q
# 888              0      0            112053   30.0000   B42        S
# 889              1      2        W./C. 6607   23.4500   NaN        S
#
# [314 rows x 11 columns]

# %%
dF1[['Name', 'Sex']]
dF1.info()

# %%
dF1['1'] = dF1['Name'].str.split().str.get(0)
dF1['2'] = dF1['Name'].str.split().str.get(1)
dF1['3'] = dF1['Name'].str.split().str.get(2)
dF1['4'] = dF1['Name'].str.split().str.get(3)
dF1['5'] = dF1['Name'].str.split().str.get(4)
dF1['3'].value_counts()
# Out:
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/aleksandrvasilcenko/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# William        13
# Mary            9
# Anna            9
# Margaret        6
# John            6
# Elizabeth       6
# Thomas          6
# Frederick       5
# Alice           5
# Ellen           4
# James           4
# Bertha          4
# Edward          4
# Helen           4
# Annie           3
# Samuel          3
# Hanora          3
# Katherine       3
# Kate            3
# Charles         3
# Henry           3
# Mrs.            3
# Joseph          3
# Frank           2
# Alexander       2
# Ida             2
# Lillian         2
# Catherine       2
# Mabel           2
# Emily           2
#                ..
# Gretchen        1
# Thamine         1
# Simonne         1
# Florence        1
# Jessie          1
# Katriina        1
# Dorothy         1
# Adele           1
# Frederic        1
# Elise           1
# Aurora          1
# Lady.           1
# Sam             1
# Eugenie         1
# Berthe          1
# Daisy           1
# Jean            1
# Julie           1
# Hjalmar         1
# Ebba            1
# Saiide          1
# Richard         1
# Margareth       1
# Leopold         1
# Virginia        1
# Eliina          1
# Amin            1
# Encarnacion     1
# Pieta           1
# Elina           1
# Name: 3, Length: 202, dtype: int64
